# %%
"""
Script para preprocesar y entrenar un modelo TNTM_SentenceTransformer con 600 documentos del dataset 20NewsGroup.
Utiliza embeddings de BERT para palabras y documentos, realiza un split de datos y aplica parches necesarios para el entrenamiento.
"""

import pickle
import torch
import pandas as pd
from tqdm import tqdm
import numpy as np
import os
import sys
sys.path.append('../TNTM/Code/TNTM')
from octis.dataset.dataset import Dataset
import TNTM_SentenceTransformer
import TNTM_inference

def load_dataset(num_docs=600):
    dataset = Dataset()
    dataset.fetch_dataset("20NewsGroup")
    corpus = dataset.get_corpus()[:num_docs]
    vocab = sorted(dataset._Dataset__vocabulary)
    print(f"Usando {len(corpus)} documentos")
    print(f"Tamaño del vocabulario: {len(vocab)}")
    return corpus, vocab

def load_word_embeddings(file_path):
    word_df = pickle.load(open(file_path, "rb"))
    
    def embeddings_to_tensor(emb_list):
        if isinstance(emb_list, list):
            return torch.stack(emb_list)
        elif isinstance(emb_list, torch.Tensor):
            return emb_list
        else:
            raise ValueError(f"Tipo inesperado: {type(emb_list)}")
    
    word_df['emb_tensor'] = word_df['embedding'].apply(embeddings_to_tensor)
    
    word_to_emb = dict(zip(word_df.index, word_df['emb_tensor']))
    embedding_dim = word_df['emb_tensor'].iloc[0].shape[0]
    
    return word_to_emb, embedding_dim

def compute_word_embeddings(vocab, word_to_emb, embedding_dim):
    word_embeddings = torch.stack([word_to_emb.get(w, torch.zeros(embedding_dim)) for w in vocab])
    print(f"word_embeddings shape: {word_embeddings.shape}")
    return word_embeddings

def compute_document_embeddings(corpus, word_to_emb, embedding_dim):
    print("Calculando embeddings de documentos...")
    document_embeddings_list = []
    for doc in tqdm(corpus, desc="Document embeddings"):
        if len(doc) == 0:
            doc_emb = torch.zeros(embedding_dim)
        else:
            doc_embs = [word_to_emb.get(w, torch.zeros(embedding_dim)) for w in doc]
            doc_emb = torch.stack(doc_embs).mean(dim=0)
        document_embeddings_list.append(doc_emb)
    
    document_embeddings = torch.stack(document_embeddings_list)
    print(f"document_embeddings shape: {document_embeddings.shape}")
    return document_embeddings

def split_dataset(n_docs):
    indices = np.arange(n_docs)
    np.random.seed(42)
    np.random.shuffle(indices)
    
    n_train = int(0.8 * n_docs)
    n_val = int(0.1 * n_docs)
    n_test = n_docs - n_train - n_val
    
    train_idx = indices[:n_train]
    val_idx = indices[n_train:n_train + n_val]
    test_idx = indices[n_train + n_val:]
    
    print(f"Split: Train={len(train_idx)}, Val={len(val_idx)}, Test={len(test_idx)}")
    return train_idx, val_idx, test_idx

def custom_collate(batch):
    document_embs, bow_tens = zip(*batch)
    document_embs = torch.stack(document_embs)
    bow_tens_dense = [t.to_dense() if t.is_sparse else t for t in bow_tens]
    bow_tens = torch.stack(bow_tens_dense)
    return document_embs, bow_tens

def patch_train_test_split():
    def patched_train_test_split(dataset, train_frac, val_frac, batch_size):
        tot_len = len(dataset)
        train_len = int(tot_len * train_frac)
        val_len = int(tot_len * val_frac)
        test_len = tot_len - train_len - val_len
        train, val, test = torch.utils.data.random_split(dataset, [train_len, val_len, test_len])
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True, collate_fn=custom_collate)
        val_loader = torch.utils.data.DataLoader(val, batch_size=batch_size, shuffle=True, collate_fn=custom_collate)
        test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=True, collate_fn=custom_collate)
        
        return train_loader, val_loader, test_loader
    
    TNTM_inference.train_test_split = patched_train_test_split

def train_model(tntm, corpus_train_val, vocab, word_embeddings, document_embeddings_train_val):
    print("Iniciando entrenamiento...")
    result = tntm.fit(
        corpus=corpus_train_val,
        vocab=vocab,
        word_embeddings=word_embeddings,
        document_embeddings=document_embeddings_train_val
    )
    print("¡Entrenamiento completado con éxito!")
    print(f"Resultados guardados en: {tntm.save_path}")
    return result

def save_test_set(save_dir, corpus, document_embeddings, test_idx):
    test_data = {
        "corpus": [corpus[i] for i in test_idx],
        "document_embeddings": document_embeddings[test_idx],
        "original_indices": test_idx.tolist()
    }
    with open(os.path.join(save_dir, "test_set_60docs.pickle"), "wb") as f:
        pickle.dump(test_data, f)
    print("Conjunto de test guardado para evaluación posterior.")

# %%
embeddings_file = "../../Data/DataResults_BERT/cleaned_embedding_df_20ng_BERT.pickle"
save_dir = "example/20_topics_600docs"
os.makedirs(save_dir, exist_ok=True)
save_path = os.path.join(save_dir, "model.pt")

corpus, vocab = load_dataset(num_docs=600)

word_to_emb, embedding_dim = load_word_embeddings(embeddings_file)
word_embeddings = compute_word_embeddings(vocab, word_to_emb, embedding_dim)

document_embeddings = compute_document_embeddings(corpus, word_to_emb, embedding_dim)
# Out:
# Usando 600 documentos
# Tamaño del vocabulario: 1612
# word_embeddings shape: torch.Size([1612, 768])
# Calculando embeddings de documentos...
# Document embeddings: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [00:00<00:00, 4443.35it/s]
# document_embeddings shape: torch.Size([600, 768])

# %%
train_idx, val_idx, test_idx = split_dataset(len(corpus))

train_val_idx = np.concatenate((train_idx, val_idx))
corpus_train_val = [corpus[i] for i in train_val_idx]
document_embeddings_train_val = document_embeddings[torch.tensor(train_val_idx)]

total_train_val = len(train_idx) + len(val_idx)
validation_set_size = 1 - ((len(train_idx) - 0.5) / total_train_val)
print(f"validation_set_size ajustado: {validation_set_size:.6f} (para evitar test vacío interno)")

tntm = TNTM_SentenceTransformer.TNTM_SentenceTransformer(
    n_topics=20,
    save_path=save_path,
    enc_lr=1e-3,
    dec_lr=1e-3,
    validation_set_size=validation_set_size
)

patch_train_test_split()

result = train_model(tntm, corpus_train_val, vocab, word_embeddings, document_embeddings_train_val)

save_test_set(save_dir, corpus, document_embeddings, test_idx)
# Out:
# Split: Train=480, Val=60, Test=60
# validation_set_size ajustado: 0.112037 (para evitar test vacío interno)
# Iniciando entrenamiento...
# /home/rod/Documents/Taller de Título/topic_models/TNTM/Code/TNTM/TNTM_SentenceTransformer.py:151: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mus_init_ten = torch.tensor(mus_init).to(self.device)
# /home/rod/Documents/Taller de Título/topic_models/TNTM/Code/TNTM/TNTM_SentenceTransformer.py:152: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   L_lower_init_ten = torch.tensor(L_lower_init).to(self.device)
# /home/rod/Documents/Taller de Título/topic_models/TNTM/Code/TNTM/TNTM_SentenceTransformer.py:153: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   log_diag_init_ten = torch.tensor(log_diag_init).to(self.device)
# Epoch nr 0: mean_train_loss = -533.7905883789062, mean_train_nl = -535.8125610351562, mean_train_kld = 2.0219759941101074, elapsed time: 0.44049572944641113
# Epoch nr 0: median_train_loss = -529.266357421875, median_train_nl = -531.46923828125, median_train_kld = 1.841023564338684, elapsed time: 0.44049572944641113
# Epoch nr 0: mean_val_loss = -524.4798583984375, mean_val_nl = -527.3729248046875, mean_val_kld = 2.8929708003997803
# Epoch nr 0: median_val_loss = -526.0178833007812, median_val_nl = -528.910888671875, median_val_kld = 2.8929708003997803
# gradient norm: mean: 679.5923169632015, median: 635.8293404095791, max: 923.7510443717642
#
#
# Epoch nr 1: mean_train_loss = -537.8261108398438, mean_train_nl = -542.606689453125, mean_train_kld = 4.780606269836426, elapsed time: 0.30364227294921875
# Epoch nr 1: median_train_loss = -550.1226196289062, median_train_nl = -554.9246826171875, median_train_kld = 4.802071571350098, elapsed time: 0.30364227294921875
# Epoch nr 1: mean_val_loss = -528.7705078125, mean_val_nl = -536.3369750976562, mean_val_kld = 7.56651496887207
# Epoch nr 1: median_val_loss = -528.0362548828125, median_val_nl = -535.6027221679688, median_val_kld = 7.566514015197754
# gradient norm: mean: 578.5214360772925, median: 577.5104370169493, max: 607.5958597079691
#
#
# Epoch nr 2: mean_train_loss = -549.4766845703125, mean_train_nl = -558.0745239257812, mean_train_kld = 8.59782886505127, elapsed time: 0.2937450408935547
# Epoch nr 2: median_train_loss = -539.375732421875, median_train_nl = -548.2548828125, median_train_kld = 8.635082244873047, elapsed time: 0.2937450408935547
# Epoch nr 2: mean_val_loss = -530.7185668945312, mean_val_nl = -540.2919921875, mean_val_kld = 9.573430061340332
# Epoch nr 2: median_val_loss = -531.06201171875, median_val_nl = -540.6354370117188, median_val_kld = 9.573431015014648
# gradient norm: mean: 531.765732997524, median: 517.2526428004601, max: 657.6832851000011
#
#
# Epoch nr 3: mean_train_loss = -554.35498046875, mean_train_nl = -564.03662109375, mean_train_kld = 9.681633949279785, elapsed time: 0.30946993827819824
# Epoch nr 3: median_train_loss = -558.6306762695312, median_train_nl = -568.2667236328125, median_train_kld = 9.668079376220703, elapsed time: 0.30946993827819824
# Epoch nr 3: mean_val_loss = -533.3447875976562, mean_val_nl = -542.8538818359375, mean_val_kld = 9.509130477905273
# Epoch nr 3: median_val_loss = -532.2734985351562, median_val_nl = -541.7825927734375, median_val_kld = 9.509129524230957
# gradient norm: mean: 456.65671955114215, median: 450.84535311137995, max: 534.2531351566893
#
#
# Epoch nr 4: mean_train_loss = -557.8881225585938, mean_train_nl = -567.1681518554688, mean_train_kld = 9.280035972595215, elapsed time: 0.29369401931762695
# Epoch nr 4: median_train_loss = -542.708984375, median_train_nl = -551.8197631835938, median_train_kld = 9.285650253295898, elapsed time: 0.29369401931762695
# Epoch nr 4: mean_val_loss = -533.7612915039062, mean_val_nl = -542.579345703125, mean_val_kld = 8.818072319030762
# Epoch nr 4: median_val_loss = -533.4263305664062, median_val_nl = -542.244384765625, median_val_kld = 8.818071365356445
# gradient norm: mean: 444.8232282206029, median: 427.65177801488676, max: 613.1048263831038
#
#
# Epoch nr 5: mean_train_loss = -555.0945434570312, mean_train_nl = -563.581787109375, mean_train_kld = 8.487264633178711, elapsed time: 0.3143949508666992
# Epoch nr 5: median_train_loss = -558.8028564453125, median_train_nl = -567.2086181640625, median_train_kld = 8.501622200012207, elapsed time: 0.3143949508666992
# Epoch nr 5: mean_val_loss = -536.0624389648438, mean_val_nl = -543.9991455078125, mean_val_kld = 7.936749458312988
# Epoch nr 5: median_val_loss = -534.2628784179688, median_val_nl = -542.1995849609375, median_val_kld = 7.936749458312988
# gradient norm: mean: 445.2216568223446, median: 426.6643599452986, max: 611.5460486320047
#
#
# Epoch nr 6: mean_train_loss = -545.84375, mean_train_nl = -553.3939208984375, mean_train_kld = 7.5501813888549805, elapsed time: 0.29582786560058594
# Epoch nr 6: median_train_loss = -531.3018188476562, median_train_nl = -538.849365234375, median_train_kld = 7.547572135925293, elapsed time: 0.29582786560058594
# Epoch nr 6: mean_val_loss = -532.7317504882812, mean_val_nl = -539.6892700195312, mean_val_kld = 6.9575676918029785
# Epoch nr 6: median_val_loss = -534.2159423828125, median_val_nl = -541.1735229492188, median_val_kld = 6.9575676918029785
# gradient norm: mean: 397.5747578663568, median: 379.90689215376756, max: 491.07869172461074
#
#
# Epoch nr 7: mean_train_loss = -575.5985717773438, mean_train_nl = -582.1285400390625, mean_train_kld = 6.529980182647705, elapsed time: 0.30655860900878906
# Epoch nr 7: median_train_loss = -503.32781982421875, median_train_nl = -509.84844970703125, median_train_kld = 6.520648956298828, elapsed time: 0.30655860900878906
# Epoch nr 7: mean_val_loss = -535.9532470703125, mean_val_nl = -541.9476928710938, mean_val_kld = 5.994490623474121
# Epoch nr 7: median_val_loss = -535.6469116210938, median_val_nl = -541.6414184570312, median_val_kld = 5.994490623474121
# gradient norm: mean: 466.49905134946164, median: 389.5769674033504, max: 736.2528751568608
#
#
# Epoch nr 8: mean_train_loss = -562.8759765625, mean_train_nl = -568.5084228515625, mean_train_kld = 5.6324992179870605, elapsed time: 0.3032393455505371
# Epoch nr 8: median_train_loss = -563.7125244140625, median_train_nl = -569.4530639648438, median_train_kld = 5.609997749328613, elapsed time: 0.3032393455505371
# Epoch nr 8: mean_val_loss = -535.0804443359375, mean_val_nl = -540.3250122070312, mean_val_kld = 5.244517803192139
# Epoch nr 8: median_val_loss = -536.6550903320312, median_val_nl = -541.8995971679688, median_val_kld = 5.244517803192139
# gradient norm: mean: 400.5472856430256, median: 384.9557002787126, max: 499.6414009296558
#
#
# Epoch nr 9: mean_train_loss = -556.2799682617188, mean_train_nl = -561.261474609375, mean_train_kld = 4.98148250579834, elapsed time: 0.2927567958831787
# Epoch nr 9: median_train_loss = -487.03948974609375, median_train_nl = -491.9867248535156, median_train_kld = 4.947226524353027, elapsed time: 0.2927567958831787
# Epoch nr 9: mean_val_loss = -535.8591918945312, mean_val_nl = -540.6306762695312, mean_val_kld = 4.771509170532227
# Epoch nr 9: median_val_loss = -534.8087158203125, median_val_nl = -539.5801391601562, median_val_kld = 4.771509170532227
# gradient norm: mean: 368.8206767557078, median: 361.3297388879996, max: 439.4305528039393
#
#
# Epoch nr 10: mean_train_loss = -572.2420043945312, mean_train_nl = -576.789794921875, mean_train_kld = 4.547844886779785, elapsed time: 0.294903039932251
# Epoch nr 10: median_train_loss = -542.57666015625, median_train_nl = -547.19970703125, median_train_kld = 4.56890869140625, elapsed time: 0.294903039932251
# Epoch nr 10: mean_val_loss = -537.6629028320312, mean_val_nl = -542.1193237304688, mean_val_kld = 4.456397533416748
# Epoch nr 10: median_val_loss = -538.1063232421875, median_val_nl = -542.5626831054688, median_val_kld = 4.456398010253906
# gradient norm: mean: 450.2700883858928, median: 347.1775255538629, max: 773.1021044621012
#
#
# Epoch nr 11: mean_train_loss = -559.4768676757812, mean_train_nl = -563.7597045898438, mean_train_kld = 4.282854080200195, elapsed time: 0.30201220512390137
# Epoch nr 11: median_train_loss = -547.0145263671875, median_train_nl = -551.2633666992188, median_train_kld = 4.288455963134766, elapsed time: 0.30201220512390137
# Epoch nr 11: mean_val_loss = -538.4470825195312, mean_val_nl = -542.7200927734375, mean_val_kld = 4.273051738739014
# Epoch nr 11: median_val_loss = -542.2575073242188, median_val_nl = -546.530517578125, median_val_kld = 4.273051738739014
# gradient norm: mean: 430.95677994300644, median: 456.3954969413852, max: 530.7387115268189
#
#
# Epoch nr 12: mean_train_loss = -563.8222045898438, mean_train_nl = -567.9575805664062, mean_train_kld = 4.13536262512207, elapsed time: 0.2987534999847412
# Epoch nr 12: median_train_loss = -551.2486572265625, median_train_nl = -555.4044189453125, median_train_kld = 4.155657768249512, elapsed time: 0.2987534999847412
# Epoch nr 12: mean_val_loss = -537.3082885742188, mean_val_nl = -541.5191040039062, mean_val_kld = 4.21088171005249
# Epoch nr 12: median_val_loss = -541.0272827148438, median_val_nl = -545.2381591796875, median_val_kld = 4.21088171005249
# gradient norm: mean: 427.3820920190426, median: 407.47314080072897, max: 534.5106286707452
#
#
# Epoch nr 13: mean_train_loss = -569.9498291015625, mean_train_nl = -574.0208129882812, mean_train_kld = 4.070979595184326, elapsed time: 0.29689884185791016
# Epoch nr 13: median_train_loss = -612.44482421875, median_train_nl = -616.546142578125, median_train_kld = 4.070448875427246, elapsed time: 0.29689884185791016
# Epoch nr 13: mean_val_loss = -539.7765502929688, mean_val_nl = -543.9431762695312, mean_val_kld = 4.166635036468506
# Epoch nr 13: median_val_loss = -539.5047607421875, median_val_nl = -543.6713256835938, median_val_kld = 4.166634559631348
# gradient norm: mean: 411.5201586191078, median: 414.95416619546234, max: 540.7202063686896
#
#
# Epoch nr 14: mean_train_loss = -559.6784057617188, mean_train_nl = -563.7117919921875, mean_train_kld = 4.033445358276367, elapsed time: 0.3063466548919678
# Epoch nr 14: median_train_loss = -507.05645751953125, median_train_nl = -511.0711975097656, median_train_kld = 4.051342010498047, elapsed time: 0.3063466548919678
# Epoch nr 14: mean_val_loss = -542.0576782226562, mean_val_nl = -546.2343139648438, mean_val_kld = 4.176657199859619
# Epoch nr 14: median_val_loss = -540.5035400390625, median_val_nl = -544.6801147460938, median_val_kld = 4.176657199859619
# gradient norm: mean: 393.11752415739403, median: 365.12634041599154, max: 508.001178418897
#
#
# Epoch nr 15: mean_train_loss = -568.0936279296875, mean_train_nl = -572.147705078125, mean_train_kld = 4.054034233093262, elapsed time: 0.30389857292175293
# Epoch nr 15: median_train_loss = -567.0430908203125, median_train_nl = -571.1328125, median_train_kld = 4.071222305297852, elapsed time: 0.30389857292175293
# Epoch nr 15: mean_val_loss = -537.8622436523438, mean_val_nl = -542.0923461914062, mean_val_kld = 4.230053424835205
# Epoch nr 15: median_val_loss = -539.7113037109375, median_val_nl = -543.9413452148438, median_val_kld = 4.230053424835205
# gradient norm: mean: 428.2014848584561, median: 433.0748988627057, max: 526.2474125242622
#
#
# Epoch nr 16: mean_train_loss = -559.2874755859375, mean_train_nl = -563.3958129882812, mean_train_kld = 4.108306884765625, elapsed time: 0.5938208103179932
# Epoch nr 16: median_train_loss = -521.692626953125, median_train_nl = -525.837890625, median_train_kld = 4.100558757781982, elapsed time: 0.5938208103179932
# Epoch nr 16: mean_val_loss = -541.503662109375, mean_val_nl = -545.8340454101562, mean_val_kld = 4.3304443359375
# Epoch nr 16: median_val_loss = -543.057373046875, median_val_nl = -547.3877563476562, median_val_kld = 4.330443859100342
# gradient norm: mean: 388.57277383621926, median: 355.3193880648479, max: 562.7674124910192
#
#
# Epoch nr 17: mean_train_loss = -572.413818359375, mean_train_nl = -576.6533203125, mean_train_kld = 4.239494323730469, elapsed time: 0.3054673671722412
# Epoch nr 17: median_train_loss = -588.0028076171875, median_train_nl = -592.2510986328125, median_train_kld = 4.24835205078125, elapsed time: 0.3054673671722412
# Epoch nr 17: mean_val_loss = -544.0372924804688, mean_val_nl = -548.5729370117188, mean_val_kld = 4.535638809204102
# Epoch nr 17: median_val_loss = -543.480712890625, median_val_nl = -548.0164184570312, median_val_kld = 4.535638809204102
# gradient norm: mean: 413.778233870692, median: 352.54146539818686, max: 621.940625547404
#
#
# Epoch nr 18: mean_train_loss = -561.2449951171875, mean_train_nl = -565.71923828125, mean_train_kld = 4.47420072555542, elapsed time: 0.299823522567749
# Epoch nr 18: median_train_loss = -467.8740539550781, median_train_nl = -472.2749328613281, median_train_kld = 4.487123966217041, elapsed time: 0.299823522567749
# Epoch nr 18: mean_val_loss = -541.4606323242188, mean_val_nl = -546.290283203125, mean_val_kld = 4.829687595367432
# Epoch nr 18: median_val_loss = -542.1893920898438, median_val_nl = -547.0191040039062, median_val_kld = 4.829687595367432
# gradient norm: mean: 371.7029610448493, median: 356.77309712328736, max: 493.7624045185703
#
#
# Epoch nr 19: mean_train_loss = -564.0, mean_train_nl = -568.7854614257812, mean_train_kld = 4.785501480102539, elapsed time: 0.3068852424621582
# Epoch nr 19: median_train_loss = -534.2454833984375, median_train_nl = -538.919921875, median_train_kld = 4.7845282554626465, elapsed time: 0.3068852424621582
# Epoch nr 19: mean_val_loss = -542.6743774414062, mean_val_nl = -547.8493041992188, mean_val_kld = 5.1749138832092285
# Epoch nr 19: median_val_loss = -542.8782958984375, median_val_nl = -548.0531616210938, median_val_kld = 5.1749138832092285
# gradient norm: mean: 406.2069680776906, median: 389.605313481922, max: 495.68069921638283
#
#
# Epoch nr 20: mean_train_loss = -567.5350341796875, mean_train_nl = -572.6636352539062, mean_train_kld = 5.128592491149902, elapsed time: 0.35015034675598145
# Epoch nr 20: median_train_loss = -552.2671508789062, median_train_nl = -557.4376220703125, median_train_kld = 5.086730480194092, elapsed time: 0.35015034675598145
# Epoch nr 20: mean_val_loss = -545.9619750976562, mean_val_nl = -551.5098876953125, mean_val_kld = 5.547837257385254
# Epoch nr 20: median_val_loss = -545.0406494140625, median_val_nl = -550.5885620117188, median_val_kld = 5.547837257385254
# gradient norm: mean: 398.09806301859766, median: 404.5629059500863, max: 467.91146950366385
#
#
# Epoch nr 21: mean_train_loss = -571.8825073242188, mean_train_nl = -577.3795166015625, mean_train_kld = 5.497011661529541, elapsed time: 0.2947542667388916
# Epoch nr 21: median_train_loss = -537.362548828125, median_train_nl = -542.9537963867188, median_train_kld = 5.520071029663086, elapsed time: 0.2947542667388916
# Epoch nr 21: mean_val_loss = -547.0590209960938, mean_val_nl = -553.009521484375, mean_val_kld = 5.950427532196045
# Epoch nr 21: median_val_loss = -546.0964965820312, median_val_nl = -552.0469970703125, median_val_kld = 5.9504265785217285
# gradient norm: mean: 405.2222999015911, median: 399.93454616672415, max: 492.16437455367156
#
#
# Epoch nr 22: mean_train_loss = -581.6746215820312, mean_train_nl = -587.588623046875, mean_train_kld = 5.914031505584717, elapsed time: 0.29678869247436523
# Epoch nr 22: median_train_loss = -546.8372192382812, median_train_nl = -552.751220703125, median_train_kld = 5.91393518447876, elapsed time: 0.29678869247436523
# Epoch nr 22: mean_val_loss = -547.2296142578125, mean_val_nl = -553.628662109375, mean_val_kld = 6.399085998535156
# Epoch nr 22: median_val_loss = -547.6454467773438, median_val_nl = -554.0445556640625, median_val_kld = 6.3990864753723145
# gradient norm: mean: 453.8323934803185, median: 387.11784964359754, max: 729.4073138478287
#
#
# Epoch nr 23: mean_train_loss = -564.22705078125, mean_train_nl = -570.6049194335938, mean_train_kld = 6.377884864807129, elapsed time: 0.3094644546508789
# Epoch nr 23: median_train_loss = -525.4647827148438, median_train_nl = -531.7314453125, median_train_kld = 6.280338287353516, elapsed time: 0.3094644546508789
# Epoch nr 23: mean_val_loss = -545.3763427734375, mean_val_nl = -552.2493896484375, mean_val_kld = 6.873034954071045
# Epoch nr 23: median_val_loss = -546.0154418945312, median_val_nl = -552.8885498046875, median_val_kld = 6.873035907745361
# gradient norm: mean: 388.3540463390077, median: 406.19083818724823, max: 424.1495416810611
#
#
# Epoch nr 24: mean_train_loss = -570.1689453125, mean_train_nl = -576.9878540039062, mean_train_kld = 6.818881034851074, elapsed time: 0.28722405433654785
# Epoch nr 24: median_train_loss = -501.11187744140625, median_train_nl = -508.2034912109375, median_train_kld = 6.7094197273254395, elapsed time: 0.28722405433654785
# Epoch nr 24: mean_val_loss = -546.306884765625, mean_val_nl = -553.5808715820312, mean_val_kld = 7.273991584777832
# Epoch nr 24: median_val_loss = -546.7300415039062, median_val_nl = -554.0039672851562, median_val_kld = 7.273991584777832
# gradient norm: mean: 409.79542787747323, median: 411.83610169715894, max: 501.91793569257493
#
#
# Epoch nr 25: mean_train_loss = -563.3367919921875, mean_train_nl = -570.4641723632812, mean_train_kld = 7.127414703369141, elapsed time: 0.30710458755493164
# Epoch nr 25: median_train_loss = -521.5812377929688, median_train_nl = -528.7317504882812, median_train_kld = 7.150509834289551, elapsed time: 0.30710458755493164
# Epoch nr 25: mean_val_loss = -547.1749877929688, mean_val_nl = -554.7791748046875, mean_val_kld = 7.604208469390869
# Epoch nr 25: median_val_loss = -548.0017700195312, median_val_nl = -555.6060180664062, median_val_kld = 7.604208469390869
# gradient norm: mean: 435.18278034721067, median: 386.2458106938252, max: 626.3116590967855
#
#
# Epoch nr 26: mean_train_loss = -573.4481201171875, mean_train_nl = -580.8671875, mean_train_kld = 7.419095039367676, elapsed time: 0.2922639846801758
# Epoch nr 26: median_train_loss = -566.30078125, median_train_nl = -573.8060302734375, median_train_kld = 7.45706844329834, elapsed time: 0.2922639846801758
# Epoch nr 26: mean_val_loss = -545.7666015625, mean_val_nl = -553.5879516601562, mean_val_kld = 7.821326732635498
# Epoch nr 26: median_val_loss = -546.6771850585938, median_val_nl = -554.4985961914062, median_val_kld = 7.82132625579834
# gradient norm: mean: 428.0319444670605, median: 422.9569110142593, max: 547.0877017585348
#
#
# Epoch nr 27: mean_train_loss = -573.3486328125, mean_train_nl = -580.92041015625, mean_train_kld = 7.571829795837402, elapsed time: 0.32422351837158203
# Epoch nr 27: median_train_loss = -516.07421875, median_train_nl = -523.6567993164062, median_train_kld = 7.582608222961426, elapsed time: 0.32422351837158203
# Epoch nr 27: mean_val_loss = -548.0813598632812, mean_val_nl = -555.992919921875, mean_val_kld = 7.911500930786133
# Epoch nr 27: median_val_loss = -546.6680908203125, median_val_nl = -554.5796508789062, median_val_kld = 7.911500930786133
# gradient norm: mean: 417.37353544857433, median: 403.8802416435461, max: 570.7012984967627
#
#
# Epoch nr 28: mean_train_loss = -565.3804931640625, mean_train_nl = -573.00830078125, mean_train_kld = 7.627760410308838, elapsed time: 0.2959589958190918
# Epoch nr 28: median_train_loss = -573.3338623046875, median_train_nl = -580.865234375, median_train_kld = 7.651264667510986, elapsed time: 0.2959589958190918
# Epoch nr 28: mean_val_loss = -547.9752197265625, mean_val_nl = -555.8798217773438, mean_val_kld = 7.90463924407959
# Epoch nr 28: median_val_loss = -549.2057495117188, median_val_nl = -557.1104125976562, median_val_kld = 7.904638767242432
# gradient norm: mean: 447.2978468861162, median: 467.8588301624285, max: 491.10817775463005
#
#
# Epoch nr 29: mean_train_loss = -576.7281494140625, mean_train_nl = -584.3033447265625, mean_train_kld = 7.575163841247559, elapsed time: 0.3023514747619629
# Epoch nr 29: median_train_loss = -576.634521484375, median_train_nl = -584.186767578125, median_train_kld = 7.598067283630371, elapsed time: 0.3023514747619629
# Epoch nr 29: mean_val_loss = -547.1688232421875, mean_val_nl = -554.9881591796875, mean_val_kld = 7.8193488121032715
# Epoch nr 29: median_val_loss = -547.6084594726562, median_val_nl = -555.427734375, median_val_kld = 7.81934928894043
# gradient norm: mean: 420.9295986469451, median: 365.89485911677684, max: 634.5089595795582
#
#
# Epoch nr 30: mean_train_loss = -578.3094482421875, mean_train_nl = -585.7677001953125, mean_train_kld = 7.458205699920654, elapsed time: 0.30183982849121094
# Epoch nr 30: median_train_loss = -584.2220458984375, median_train_nl = -591.714599609375, median_train_kld = 7.444334983825684, elapsed time: 0.30183982849121094
# Epoch nr 30: mean_val_loss = -547.2408447265625, mean_val_nl = -554.9252319335938, mean_val_kld = 7.6843695640563965
# Epoch nr 30: median_val_loss = -550.8008422851562, median_val_nl = -558.4852294921875, median_val_kld = 7.684370040893555
# gradient norm: mean: 420.2729736965182, median: 424.47309762951124, max: 508.4406640717323
#
#
# Epoch nr 31: mean_train_loss = -587.106689453125, mean_train_nl = -594.4013671875, mean_train_kld = 7.294696807861328, elapsed time: 0.3037707805633545
# Epoch nr 31: median_train_loss = -563.73681640625, median_train_nl = -571.0279541015625, median_train_kld = 7.291257858276367, elapsed time: 0.3037707805633545
# Epoch nr 31: mean_val_loss = -549.505859375, mean_val_nl = -557.0048217773438, mean_val_kld = 7.498974323272705
# Epoch nr 31: median_val_loss = -548.194580078125, median_val_nl = -555.6935424804688, median_val_kld = 7.498974800109863
# gradient norm: mean: 419.49907098087164, median: 363.4760565370194, max: 649.0618416178463
#
#
# Epoch nr 32: mean_train_loss = -569.8449096679688, mean_train_nl = -576.9204711914062, mean_train_kld = 7.075568675994873, elapsed time: 0.3004021644592285
# Epoch nr 32: median_train_loss = -567.629638671875, median_train_nl = -574.7315673828125, median_train_kld = 7.049171447753906, elapsed time: 0.3004021644592285
# Epoch nr 32: mean_val_loss = -548.5137329101562, mean_val_nl = -555.7950439453125, mean_val_kld = 7.2812886238098145
# Epoch nr 32: median_val_loss = -549.0252075195312, median_val_nl = -556.3065185546875, median_val_kld = 7.2812886238098145
# gradient norm: mean: 424.3273835011217, median: 414.07660035903945, max: 518.4307867700236
#
#
# Epoch nr 33: mean_train_loss = -570.515380859375, mean_train_nl = -577.3790283203125, mean_train_kld = 6.863670825958252, elapsed time: 0.399960994720459
# Epoch nr 33: median_train_loss = -513.8905029296875, median_train_nl = -520.8480224609375, median_train_kld = 6.905653953552246, elapsed time: 0.399960994720459
# Epoch nr 33: mean_val_loss = -549.2442626953125, mean_val_nl = -556.2902221679688, mean_val_kld = 7.045941352844238
# Epoch nr 33: median_val_loss = -548.0794067382812, median_val_nl = -555.1253051757812, median_val_kld = 7.045941352844238
# gradient norm: mean: 394.79006218290476, median: 388.9618178268808, max: 451.4468230461858
#
#
# Epoch nr 34: mean_train_loss = -566.0751953125, mean_train_nl = -572.692626953125, mean_train_kld = 6.617435455322266, elapsed time: 0.4002189636230469
# Epoch nr 34: median_train_loss = -560.4373168945312, median_train_nl = -567.145751953125, median_train_kld = 6.677753448486328, elapsed time: 0.4002189636230469
# Epoch nr 34: mean_val_loss = -549.5806884765625, mean_val_nl = -556.4091186523438, mean_val_kld = 6.828444957733154
# Epoch nr 34: median_val_loss = -551.0753173828125, median_val_nl = -557.9037475585938, median_val_kld = 6.828444480895996
# gradient norm: mean: 407.68299982584745, median: 402.78768392424166, max: 547.4632572850645
#
#
# Epoch nr 35: mean_train_loss = -569.40087890625, mean_train_nl = -575.7920532226562, mean_train_kld = 6.391199588775635, elapsed time: 0.3482956886291504
# Epoch nr 35: median_train_loss = -499.94207763671875, median_train_nl = -506.3687744140625, median_train_kld = 6.400152206420898, elapsed time: 0.3482956886291504
# Epoch nr 35: mean_val_loss = -547.502197265625, mean_val_nl = -554.1503295898438, mean_val_kld = 6.648100852966309
# Epoch nr 35: median_val_loss = -551.437744140625, median_val_nl = -558.0859375, median_val_kld = 6.648101806640625
# gradient norm: mean: 430.7581769746913, median: 380.49663355234964, max: 635.5451127482057
#
#
# Epoch nr 36: mean_train_loss = -581.8289794921875, mean_train_nl = -588.0325927734375, mean_train_kld = 6.203604698181152, elapsed time: 0.3013784885406494
# Epoch nr 36: median_train_loss = -596.9755859375, median_train_nl = -603.31298828125, median_train_kld = 6.198346138000488, elapsed time: 0.3013784885406494
# Epoch nr 36: mean_val_loss = -553.2406005859375, mean_val_nl = -559.7357788085938, mean_val_kld = 6.4951581954956055
# Epoch nr 36: median_val_loss = -551.788818359375, median_val_nl = -558.283935546875, median_val_kld = 6.49515962600708
# gradient norm: mean: 450.3330801421081, median: 405.99285714224106, max: 681.4886112387901
#
#
# Epoch nr 37: mean_train_loss = -588.8568725585938, mean_train_nl = -594.9280395507812, mean_train_kld = 6.071207046508789, elapsed time: 0.3321492671966553
# Epoch nr 37: median_train_loss = -542.6685180664062, median_train_nl = -548.6323852539062, median_train_kld = 6.096096038818359, elapsed time: 0.3321492671966553
# Epoch nr 37: mean_val_loss = -551.4913940429688, mean_val_nl = -557.8430786132812, mean_val_kld = 6.351720333099365
# Epoch nr 37: median_val_loss = -549.1477661132812, median_val_nl = -555.4994506835938, median_val_kld = 6.351720333099365
# gradient norm: mean: 448.0209911836308, median: 391.4188832861591, max: 701.7033290242974
#
#
# Epoch nr 38: mean_train_loss = -575.2439575195312, mean_train_nl = -581.1748046875, mean_train_kld = 5.930927276611328, elapsed time: 0.37752413749694824
# Epoch nr 38: median_train_loss = -571.0877685546875, median_train_nl = -576.9266967773438, median_train_kld = 5.858170986175537, elapsed time: 0.37752413749694824
# Epoch nr 38: mean_val_loss = -550.623779296875, mean_val_nl = -556.9193725585938, mean_val_kld = 6.2956342697143555
# Epoch nr 38: median_val_loss = -548.7806396484375, median_val_nl = -555.0762939453125, median_val_kld = 6.295633792877197
# gradient norm: mean: 423.421207358821, median: 413.3012782021542, max: 486.33314703549104
#
#
# Epoch nr 39: mean_train_loss = -579.2772216796875, mean_train_nl = -585.172607421875, mean_train_kld = 5.895411968231201, elapsed time: 0.3689231872558594
# Epoch nr 39: median_train_loss = -627.072021484375, median_train_nl = -632.972412109375, median_train_kld = 5.890435695648193, elapsed time: 0.3689231872558594
# Epoch nr 39: mean_val_loss = -553.768310546875, mean_val_nl = -560.0679321289062, mean_val_kld = 6.299642562866211
# Epoch nr 39: median_val_loss = -550.5708618164062, median_val_nl = -556.8704833984375, median_val_kld = 6.299642562866211
# gradient norm: mean: 477.05811198656284, median: 479.12043056314815, max: 599.2394573880804
#
#
# Epoch nr 40: mean_train_loss = -589.6072998046875, mean_train_nl = -595.5020141601562, mean_train_kld = 5.894745349884033, elapsed time: 0.3424243927001953
# Epoch nr 40: median_train_loss = -556.0126953125, median_train_nl = -561.78515625, median_train_kld = 5.850195407867432, elapsed time: 0.3424243927001953
# Epoch nr 40: mean_val_loss = -553.1616821289062, mean_val_nl = -559.5022583007812, mean_val_kld = 6.340583801269531
# Epoch nr 40: median_val_loss = -553.3549194335938, median_val_nl = -559.695556640625, median_val_kld = 6.340583801269531
# gradient norm: mean: 537.5348611726938, median: 414.8804198855356, max: 1009.8744638486819
#
#
# Epoch nr 41: mean_train_loss = -571.0126342773438, mean_train_nl = -576.9695434570312, mean_train_kld = 5.956930160522461, elapsed time: 0.3152289390563965
# Epoch nr 41: median_train_loss = -516.88232421875, median_train_nl = -523.0220947265625, median_train_kld = 5.9290361404418945, elapsed time: 0.3152289390563965
# Epoch nr 41: mean_val_loss = -547.8893432617188, mean_val_nl = -554.2822265625, mean_val_kld = 6.3929572105407715
# Epoch nr 41: median_val_loss = -548.5726318359375, median_val_nl = -554.9656372070312, median_val_kld = 6.39295768737793
# gradient norm: mean: 482.9856325285457, median: 499.3912842145085, max: 573.1995896223693
#
#
# Epoch nr 42: mean_train_loss = -573.224609375, mean_train_nl = -579.1809692382812, mean_train_kld = 5.956416130065918, elapsed time: 0.3281562328338623
# Epoch nr 42: median_train_loss = -545.27294921875, median_train_nl = -551.250732421875, median_train_kld = 5.934976577758789, elapsed time: 0.3281562328338623
# Epoch nr 42: mean_val_loss = -550.4020385742188, mean_val_nl = -556.8651733398438, mean_val_kld = 6.463201999664307
# Epoch nr 42: median_val_loss = -550.7205810546875, median_val_nl = -557.183837890625, median_val_kld = 6.463201522827148
# gradient norm: mean: 541.8672578143562, median: 488.17922951322123, max: 807.2374590102146
#
#
# Epoch nr 43: mean_train_loss = -573.32958984375, mean_train_nl = -579.3818969726562, mean_train_kld = 6.052290916442871, elapsed time: 0.35183215141296387
# Epoch nr 43: median_train_loss = -576.9293212890625, median_train_nl = -582.9822998046875, median_train_kld = 6.051522254943848, elapsed time: 0.35183215141296387
# Epoch nr 43: mean_val_loss = -552.1671142578125, mean_val_nl = -558.717529296875, mean_val_kld = 6.550426006317139
# Epoch nr 43: median_val_loss = -551.4359130859375, median_val_nl = -557.9863891601562, median_val_kld = 6.5504255294799805
# gradient norm: mean: 476.1038665362907, median: 421.92226906645647, max: 712.4856647776786
#
#
# Epoch nr 44: mean_train_loss = -588.2431640625, mean_train_nl = -594.3280029296875, mean_train_kld = 6.0848388671875, elapsed time: 0.3492884635925293
# Epoch nr 44: median_train_loss = -566.4384765625, median_train_nl = -572.672119140625, median_train_kld = 6.104877471923828, elapsed time: 0.3492884635925293
# Epoch nr 44: mean_val_loss = -552.3701782226562, mean_val_nl = -558.9898681640625, mean_val_kld = 6.619706630706787
# Epoch nr 44: median_val_loss = -551.3759765625, median_val_nl = -557.9957275390625, median_val_kld = 6.619707107543945
# gradient norm: mean: 517.5127160263712, median: 402.13359626024834, max: 895.9869668192598
#
#
# Epoch nr 45: mean_train_loss = -571.9519653320312, mean_train_nl = -578.1236572265625, mean_train_kld = 6.171785831451416, elapsed time: 0.34200525283813477
# Epoch nr 45: median_train_loss = -564.909912109375, median_train_nl = -571.1109619140625, median_train_kld = 6.201202869415283, elapsed time: 0.34200525283813477
# Epoch nr 45: mean_val_loss = -552.115234375, mean_val_nl = -558.8692626953125, mean_val_kld = 6.754059791564941
# Epoch nr 45: median_val_loss = -550.8461303710938, median_val_nl = -557.6002197265625, median_val_kld = 6.754059791564941
# gradient norm: mean: 455.1872903922808, median: 440.875935419347, max: 567.0379457933213
#
#
# Epoch nr 46: mean_train_loss = -575.0096435546875, mean_train_nl = -581.2660522460938, mean_train_kld = 6.256407737731934, elapsed time: 0.34725403785705566
# Epoch nr 46: median_train_loss = -567.3603515625, median_train_nl = -573.6434326171875, median_train_kld = 6.22973108291626, elapsed time: 0.34725403785705566
# Epoch nr 46: mean_val_loss = -553.2637329101562, mean_val_nl = -560.0977172851562, mean_val_kld = 6.833956241607666
# Epoch nr 46: median_val_loss = -550.0996704101562, median_val_nl = -556.93359375, median_val_kld = 6.833956718444824
# gradient norm: mean: 464.736596050168, median: 454.233750514206, max: 587.6215392165664
#
#
# Epoch nr 47: mean_train_loss = -576.6519775390625, mean_train_nl = -582.973876953125, mean_train_kld = 6.321834564208984, elapsed time: 0.3582432270050049
# Epoch nr 47: median_train_loss = -591.2048950195312, median_train_nl = -597.6040649414062, median_train_kld = 6.3551483154296875, elapsed time: 0.3582432270050049
# Epoch nr 47: mean_val_loss = -553.3265991210938, mean_val_nl = -560.2098388671875, mean_val_kld = 6.883176803588867
# Epoch nr 47: median_val_loss = -552.125, median_val_nl = -559.0081787109375, median_val_kld = 6.883176803588867
# gradient norm: mean: 479.66720296971323, median: 484.62839536396945, max: 598.8459372147512
#
#
# Epoch nr 48: mean_train_loss = -578.0796508789062, mean_train_nl = -584.4647216796875, mean_train_kld = 6.385150909423828, elapsed time: 0.3652338981628418
# Epoch nr 48: median_train_loss = -535.9263916015625, median_train_nl = -542.356201171875, median_train_kld = 6.395415306091309, elapsed time: 0.3652338981628418
# Epoch nr 48: mean_val_loss = -554.2343139648438, mean_val_nl = -561.1604614257812, mean_val_kld = 6.926157474517822
# Epoch nr 48: median_val_loss = -552.7783203125, median_val_nl = -559.7044677734375, median_val_kld = 6.926157474517822
# gradient norm: mean: 461.8819433295522, median: 468.74364559717617, max: 532.6357936192512
#
#
# Epoch nr 49: mean_train_loss = -576.3516845703125, mean_train_nl = -582.7662353515625, mean_train_kld = 6.414580821990967, elapsed time: 0.3429141044616699
# Epoch nr 49: median_train_loss = -540.447021484375, median_train_nl = -546.9332275390625, median_train_kld = 6.396489143371582, elapsed time: 0.3429141044616699
# Epoch nr 49: mean_val_loss = -553.8212890625, mean_val_nl = -560.7809448242188, mean_val_kld = 6.959608554840088
# Epoch nr 49: median_val_loss = -553.6021118164062, median_val_nl = -560.5616455078125, median_val_kld = 6.959609031677246
# gradient norm: mean: 426.4063740380367, median: 431.6051421028144, max: 477.40542649153014
#
#
# Epoch nr 50: mean_train_loss = -572.2297973632812, mean_train_nl = -578.6646728515625, mean_train_kld = 6.434903144836426, elapsed time: 0.3788304328918457
# Epoch nr 50: median_train_loss = -519.1666259765625, median_train_nl = -525.6873779296875, median_train_kld = 6.361258506774902, elapsed time: 0.3788304328918457
# Epoch nr 50: mean_val_loss = -554.8543701171875, mean_val_nl = -561.8455810546875, mean_val_kld = 6.991185188293457
# Epoch nr 50: median_val_loss = -552.3245239257812, median_val_nl = -559.3157348632812, median_val_kld = 6.991185188293457
# gradient norm: mean: 465.50558238707714, median: 429.53893177559894, max: 608.9625700604514
#
#
# Epoch nr 51: mean_train_loss = -601.0738525390625, mean_train_nl = -607.5223388671875, mean_train_kld = 6.448493003845215, elapsed time: 0.34142422676086426
# Epoch nr 51: median_train_loss = -536.8375244140625, median_train_nl = -543.5590209960938, median_train_kld = 6.3809123039245605, elapsed time: 0.34142422676086426
# Epoch nr 51: mean_val_loss = -554.7272338867188, mean_val_nl = -561.7639770507812, mean_val_kld = 7.036798000335693
# Epoch nr 51: median_val_loss = -553.875244140625, median_val_nl = -560.9121704101562, median_val_kld = 7.036798000335693
# gradient norm: mean: 458.9244233121838, median: 360.3925907449192, max: 784.6750210356599
#
#
# Epoch nr 52: mean_train_loss = -572.4444580078125, mean_train_nl = -578.9918212890625, mean_train_kld = 6.5473504066467285, elapsed time: 0.33875465393066406
# Epoch nr 52: median_train_loss = -566.8224487304688, median_train_nl = -573.3194580078125, median_train_kld = 6.576260566711426, elapsed time: 0.33875465393066406
# Epoch nr 52: mean_val_loss = -556.0213012695312, mean_val_nl = -563.1589965820312, mean_val_kld = 7.1377482414245605
# Epoch nr 52: median_val_loss = -554.2272338867188, median_val_nl = -561.3650512695312, median_val_kld = 7.1377482414245605
# gradient norm: mean: 459.7019003625797, median: 477.4420948401407, max: 517.9655444429962
#
#
# Epoch nr 53: mean_train_loss = -594.5135498046875, mean_train_nl = -601.16943359375, mean_train_kld = 6.655899524688721, elapsed time: 0.3058314323425293
# Epoch nr 53: median_train_loss = -559.2880249023438, median_train_nl = -565.856689453125, median_train_kld = 6.631686210632324, elapsed time: 0.3058314323425293
# Epoch nr 53: mean_val_loss = -553.255859375, mean_val_nl = -560.501220703125, mean_val_kld = 7.245331764221191
# Epoch nr 53: median_val_loss = -553.6669311523438, median_val_nl = -560.9122314453125, median_val_kld = 7.245331764221191
# gradient norm: mean: 480.92598501958287, median: 429.76194803145086, max: 717.6127719888362
#
#
# Epoch nr 54: mean_train_loss = -587.6677856445312, mean_train_nl = -594.4041137695312, mean_train_kld = 6.736341953277588, elapsed time: 0.31754231452941895
# Epoch nr 54: median_train_loss = -589.8597412109375, median_train_nl = -596.5418701171875, median_train_kld = 6.682135105133057, elapsed time: 0.31754231452941895
# Epoch nr 54: mean_val_loss = -554.4594116210938, mean_val_nl = -561.8507690429688, mean_val_kld = 7.391350746154785
# Epoch nr 54: median_val_loss = -554.927490234375, median_val_nl = -562.3187866210938, median_val_kld = 7.391351222991943
# gradient norm: mean: 447.568811813863, median: 425.34128478117907, max: 563.1504522426895
#
#
# Epoch nr 55: mean_train_loss = -580.3275146484375, mean_train_nl = -587.1663818359375, mean_train_kld = 6.838919639587402, elapsed time: 0.32276272773742676
# Epoch nr 55: median_train_loss = -595.8277587890625, median_train_nl = -602.5889892578125, median_train_kld = 6.916604995727539, elapsed time: 0.32276272773742676
# Epoch nr 55: mean_val_loss = -554.6359252929688, mean_val_nl = -562.156494140625, mean_val_kld = 7.520668029785156
# Epoch nr 55: median_val_loss = -554.9993896484375, median_val_nl = -562.5200805664062, median_val_kld = 7.520667552947998
# gradient norm: mean: 482.6094677721042, median: 494.85962293424, max: 571.1007486447302
#
#
# Epoch nr 56: mean_train_loss = -590.1661987304688, mean_train_nl = -597.1268310546875, mean_train_kld = 6.960661888122559, elapsed time: 0.2983856201171875
# Epoch nr 56: median_train_loss = -589.3723754882812, median_train_nl = -596.2621459960938, median_train_kld = 6.889805316925049, elapsed time: 0.2983856201171875
# Epoch nr 56: mean_val_loss = -554.548583984375, mean_val_nl = -562.1934814453125, mean_val_kld = 7.644927501678467
# Epoch nr 56: median_val_loss = -554.3240966796875, median_val_nl = -561.9690551757812, median_val_kld = 7.644927024841309
# gradient norm: mean: 485.75394190906826, median: 422.42310571730053, max: 760.2421303935005
#
#
# Epoch nr 57: mean_train_loss = -587.2698364257812, mean_train_nl = -594.383544921875, mean_train_kld = 7.113703727722168, elapsed time: 0.31943511962890625
# Epoch nr 57: median_train_loss = -606.1741943359375, median_train_nl = -613.0327758789062, median_train_kld = 7.09739351272583, elapsed time: 0.31943511962890625
# Epoch nr 57: mean_val_loss = -554.748046875, mean_val_nl = -562.4993286132812, mean_val_kld = 7.7513322830200195
# Epoch nr 57: median_val_loss = -553.2124633789062, median_val_nl = -560.9638061523438, median_val_kld = 7.751333236694336
# gradient norm: mean: 484.06350257263693, median: 425.09626867751075, max: 696.9173692201665
#
#
# Epoch nr 58: mean_train_loss = -584.0525512695312, mean_train_nl = -591.2296142578125, mean_train_kld = 7.1770243644714355, elapsed time: 0.30253028869628906
# Epoch nr 58: median_train_loss = -618.6707763671875, median_train_nl = -625.7935180664062, median_train_kld = 7.191861152648926, elapsed time: 0.30253028869628906
# Epoch nr 58: mean_val_loss = -555.093505859375, mean_val_nl = -562.8978881835938, mean_val_kld = 7.804501533508301
# Epoch nr 58: median_val_loss = -554.8510131835938, median_val_nl = -562.655517578125, median_val_kld = 7.804502010345459
# gradient norm: mean: 420.6044124169201, median: 432.65864893353904, max: 496.29145363444445
#
#
# Epoch nr 59: mean_train_loss = -579.1595458984375, mean_train_nl = -586.3612670898438, mean_train_kld = 7.201719284057617, elapsed time: 0.5973551273345947
# Epoch nr 59: median_train_loss = -599.6759033203125, median_train_nl = -607.0797729492188, median_train_kld = 7.019181728363037, elapsed time: 0.5973551273345947
# Epoch nr 59: mean_val_loss = -555.2642822265625, mean_val_nl = -563.0933227539062, mean_val_kld = 7.829038619995117
# Epoch nr 59: median_val_loss = -552.044677734375, median_val_nl = -559.8737182617188, median_val_kld = 7.829039096832275
# gradient norm: mean: 461.07606692307496, median: 431.75457868839794, max: 603.1133795325936
#
#
# Early stopping because the median validation loss has not decreased since the last 10 epochs
# ¡Entrenamiento completado con éxito!
# Resultados guardados en: example/20_topics_600docs/model.pt
# Conjunto de test guardado para evaluación posterior.
